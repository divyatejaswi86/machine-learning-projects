# %% [markdown]
# <a href="https://colab.research.google.com/github/divyatejaswi86/machine-learning-projects/blob/main/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Step 1: Install and Import Required Libraries

# Install NLP libraries
# !pip install nltk textblob

# Import NLTK (Natural Language Toolkit) for text preprocessing
import nltk

# Import TextBlob for simple sentiment analysis and NLP tasks
from textblob import TextBlob

# Download essential NLTK data (tokenizers, stopwords)
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.13/dist-packages (3.9.1)
# Requirement already satisfied: textblob in /usr/local/lib/python3.13/dist-packages (0.19.0)
# Requirement already satisfied: click in /usr/local/lib/python3.13/dist-packages (from nltk) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.13/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.13/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from nltk) (4.67.3)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
 # @title Step 2
'''
Let's define some example movie reviews
'''
review1 = 'Must watch movie it was a great family entertainer'
review2 = 'It was okay, and the story was fine and little boring'
review3 = 'The film was awful and a complete waste of time.'

# %%
# @title Step 3: Sentiment Analysis With TextBlob
# Analyze each review using TextBlob
for review in [review1,review2,review3]:
  blob = TextBlob(review)
  sentiment = blob.sentiment.polarity # Get sentiment polarity (-1 to +1)

  # Interpret sentiment
  if sentiment > 0.3:
    label = "Positive"
  elif sentiment < -0.3:
    label = "Negative"
  else:
    label = "Neutral"

  # Print Result
  print(f"Review: {review}")
  print(f"Sentiment Score: {sentiment} ➡️ {label}")
# Out:
# Review: Must watch movie it was a great family entertainer
# Sentiment Score: 0.8 ➡️ Positive
# Review: It was okay, and the story was fine and little boring
# Sentiment Score: -0.06770833333333331 ➡️ Neutral
# Review: The film was awful and a complete waste of time.
# Sentiment Score: -0.3666666666666667 ➡️ Negative

# %%
# @title Step 4: Tokenization and Stopword Removal

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Sample text for processing
text = "Natural Language Processing makes the machines understand human language."

# Tokenize (split text into words)
tokens = word_tokenize(text)
print("Tokens:", tokens)

# Load stopwords (common words that add littlle meaning)
stop_words = set(stopwords.words('english'))

# Remove Stopwords
filtered_words = [word for word in tokens if word.lower() not in stop_words]
print("After Stopword Removal", filtered_words)
# Out:
# Tokens: ['Natural', 'Language', 'Processing', 'makes', 'the', 'machines', 'understand', 'human', 'language', '.']
# After Stopword Removal ['Natural', 'Language', 'Processing', 'makes', 'machines', 'understand', 'human', 'language', '.']

# %%
# @title Step 5: NLP Project code

user_text = input("Enter your review or comment")

# Create a TextBlob object
blob = TextBlob(user_text)

# Get the sentiment score -1 to +1
sentiment_score = blob.sentiment.polarity

# determine sentiment label
if sentiment_score > 0.3:
  sentiment_label = "Positive😊"
elif sentiment_score < -0.3:
  sentiment_label = "Negative😒"
else:
  sentiment_label = "Neutral😐"


print("Sentiment Analysis Score")
print(f"Text : {user_text}")
print(f"Sentiment Score: {sentiment_score}")
print(f"Sentiment: {sentiment_label}")
# Out:
# Enter your review or commentnot good
# Sentiment Analysis Score
# Text : not good
# Sentiment Score: -0.35
# Sentiment: Negative😒

# %%
# @title Step 1: Install and Import PyTorch
import torch

print('PyTorch version', torch.__version__)
# Out:
# PyTorch version 2.11.0+cpu

# %%
# @title Mini Real-World Example: Linear Regression with PyTorch
# Predict y = 2x + 1
# Step 1: Create sample data
x = torch.tensor([[1.0],[2.0],[3.0],[4.0]]) # Input Feature
y = torch.tensor([[3.0],[5.0],[7.0],[9.0]]) # Target (Prediction, labels) (y=2x+1)

# %%
# @title Step 2: Define a Simple Linear Model

# Import required PyTorch modules
import torch.nn as nn

# Define a linear model with 1 input and 1 ouput
model = nn.Linear(in_features = 1, out_features = 1)

# Print Model paramters
print("model parameters", list(model.parameters()))
# Out:
# model parameters [Parameter containing:
# tensor([[-0.5364]], requires_grad=True), Parameter containing:
# tensor([0.8092], requires_grad=True)]

# %%
# @title Step 3: Define Loss Function and Optimizer

# define the mean sqaured error loss (Loss function measures how far predictions are from actual values)
criterion = nn.MSELoss()

# Use Stohastic Gradient Descent (SGD) optimizer (Optimzer updates weights to minimize the loss)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01)

# %%
# @title Step 4: Train the model

# Training loop for 100 epochs
for epoch in range(100):
  # Forward pass: predict y using model
  y_pred = model(x)
  # 11 - 2
  # Compute loss
  loss = criterion(y_pred, y)

  # Backward loss: compute gradients (optimizer)
  optimizer.zero_grad()
  loss.backward()

  # Update model weights
  optimizer.step()

  # Print loss every 20 epochs
  if (epoch + 1) % 20 == 0:
    print(f"Epoch [{epoch+1}/100], Loss: {loss.item():.4f}")
# Out:
# Epoch [20/100], Loss: 0.1029
# Epoch [40/100], Loss: 0.0480
# Epoch [60/100], Loss: 0.0425
# Epoch [80/100], Loss: 0.0377
# Epoch [100/100], Loss: 0.0335

# %%
# @title Step 5: Test the Model
x_test = torch.tensor([[15.0]])
y_test_pred = model(x_test)

print("Predicted value for x = 5", y_test_pred.item())
# Out:
# Predicted value for x = 5 29.169723510742188
